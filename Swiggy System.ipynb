# %%
#Ordering a food iteam from the Swiggy by applying the promocodes

# %%
hotel=['Rasika','MyMate','Nandan']

Rasika={'Paneer Butter Masala':330,'Naan':40,'Cheese Butter Masala':380,'Butter Naan':50,'Pizza':110,'Fries':60}
MyMate={'Pizza':100,'Burger':60,'French Fries':45,'Cold Coffee':50,'Tea':20,'Vadapav':25}
Nandan={'Tandoori Pizza':150,'Margretta Pizza':120,'Garlic Bread':70,'Pepsi':20,'Tandoori Sauce':25}

rasika_order=0
mymate_order=0
nandan_order=0

rasika_promocode="STEALDEAL"
mymate_promocode="FLAT100"
nandan_promocode="GET150"
Promocode="GET175"

selecth=print("Select the hotel from where you want to order the food")
print("Rasika\nMyMate\nNandan")
Hotel=input("Enter the hotel")


if Hotel=="Rasika":
    print("Thankyou for choosing us")
    print("Please Enter the Food Item you want to order.Here is the dishes:")
    print("Paneer Butter Masala:330\nNaan:40\nCheese Butter Masala:380\nButter Naan:50\nFries:60\nPizza:110")
    item1=input("Enter your First Item")
    if item1 in Rasika:
        rasika_order=rasika_order+Rasika[item1]
        print("Your Order is successfully placed")
    else:
        print("Please order something that is present in the menu")
    
    another_item=input("Do you want to place another order? (Yes/No)")
    if(another_item=="Yes"):
        item_2=input("Enter the name of another food item")
        if item_2 in Rasika:
            rasika_order=rasika_order+Rasika[item_2]
            print("Your Second order is successfully placed")
        else:
            print("Please order something that is present in the menu")

    
    print("Order Total=",rasika_order)
    if (rasika_order>=150 and rasika_order<250):
        print("Do you want to apply promocode(Yes/No)")
        option=input()
        if option=="Yes":
            print("Enter the promocode")
            promo=input()
            if promo==rasika_promocode:
                print("Promo Code Successfully applied")
                rasika_order=rasika_order-90
            else:
                print("Please Enter Valid Promo Code")


        else:
            print("Okay")

    elif rasika_order>=250:
        print("Do you want to apply promocode(Yes/No)")
        option1=input() 
        if option1=="Yes":
            print("Enter the promocode")
            promo1=input()
            if promo1==Promocode:
                print("Promo Code Successfully applied")
                rasika_order=rasika_order-175
            else:
                print("Please Enter Valid Promo Code")

    else:
        print("No promocode applicable")
    
    print("GST on restaurant= 14 Rs")
    print("Platform Fee= 6 Rs")
    print("Delivery Fee= Free")
    rasika_order=rasika_order+20
    print("Order Total =",rasika_order)


if Hotel=="MyMate":
    print("Thankyou for choosing us")
    print("Please Enter the Food Item you want to order.Here is the dishes:")
    print("Pizza':100,'Burger':60,'French Fries':45,'Cold Coffee':50,'Tea':20,'Vadapav':25")
    item1=input("Enter your First Item")
    if item1 in MyMate:
        mymate_order=mymate_order+MyMate[item1]
        print("Your Order is successfully placed")
    else:
        print("Please order something that is present in the menu")
    
    another_item=input("Do you want to place another order? (Yes/No)")
    if(another_item=="Yes"):
        item_2=input("Enter the name of another food item")
        if item_2 in MyMate:
            mymate_order=mymate_order+MyMate[item_2]
            print("Your Second order is successfully placed")
        else:
            print("Please order something that is present in the menu")

    
    print("Order Total=",mymate_order)
    
    if (mymate_order>=150 and mymate_order<250):
        print("Do you want to apply promocode(Yes/No)")
        option=input()
        if option=="Yes":
            print("Enter the promocode")
            promo=input()
            if promo==mymate_promocode:
                print("Promo Code Successfully applied")
                mymate_order=mymate_order-90
            else:
                print("Please Enter Valid Promo Code")


        else:
            print("Okay")

    elif mymate_order>=250:
        print("Do you want to apply promocode(Yes/No)")
        option1=input() 
        if option1=="Yes":
            print("Enter the promocode")
            promo1=input()
            if promo1==Promocode:
                print("Promo Code Successfully applied")
                rasika_order=mymate_order-175
            else:
                print("Please Enter Valid Promo Code")

    else:
        print("No promocode applicable")
    
    print("GST on restaurant= 14 Rs")
    print("Platform Fee= 6 Rs")
    print("Delivery Fee= Free")
    mymate_order=mymate_order+20
    print("Order Total =",mymate_order)




if(Hotel=="Nandan"):
    print("Thankyou for choosing us")
    print("Please Enter the Food Item you want to order.Here is the dishes:")
    print("Tandoori Pizza':150,'Margretta Pizza':120,'Garlic Bread':70,'Pepsi':20,'Tandoori Sauce':25")
    item1=input("Enter your First Item")
    if item1 in Nandan:
        nandan_order=nandan_order+Nandan[item1]
        print("Your Order is successfully placed")
    else:
        print("Please order something that is present in the menu")

    
    another_item=input("Do you want to place another order? (Yes/No)")
    if(another_item=="Yes"):
        item_2=input("Enter the name of another food item")
        if item_2 in Nandan:
            nandan_order=nandan_order+Nandan[item_2]
            print("Your Second order is successfully placed")
        else:
            print("Please order something that is present in the menu")

    
    print("Order Total=",nandan_order)
   
    if (nandan_order>=150):
        print("Do you want to apply promocode(Yes/No)")
        option=input()
        if option=="Yes":
            print("Enter the promocode")
            promo=input()
            if promo==nandan_promocode:
                print("Promo Code Successfully applied")
                nandan_order=nandan_order-90
            else:
                print("Please Enter Valid Promo Code")


        else:
            print("Okay")

    
    else:
        print("No promocode applicable")
    
    print("GST on restaurant= 14 Rs")
    print("Platform Fee= 6 Rs")
    print("Delivery Fee= Free")
    nandan_order=nandan_order+20
    print("Order Total =",nandan_order)
